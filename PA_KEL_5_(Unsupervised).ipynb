# %% [markdown]
# <a href="https://colab.research.google.com/github/harist13/PA-DATAMINING-C1-KEL5/blob/main/PA_KEL_5_(Unsupervised).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Anggota kelompok 5 C1
# <br><br>
# Sulpisius Bernikusti Mentik **(2109116094)**
# <br>
# Marliani Rura **(2109116096)**
# <br>
# Muhammad Harist Illyasa **(2109116101)**

# %% [markdown]
# #**UNSUPERVISED**

# %% [markdown]
# ## (3) Analisis

# %% [markdown]
# <img src="https://th.bing.com/th/id/R.f8efea41ae3cd96d86fbc5b10f81ad77?rik=K4Dr%2biIaVGvW8g&riu=http%3a%2f%2fwww.dataprix.com%2ffiles%2fCRISPDM%2fMetodologia_CRISP_DM1_html_52cdbecf.png&ehk=6ONLJMCVxE421Sjt2JJPE6MfCzrL7LLhDZQPdkJTLcw%3d&risl=&pid=ImgRaw&r=0"/>

# %% [markdown]
# ##Business Understanding

# %% [markdown]
# Dataset New York City Airbnb Open Data berisi informasi mengenai daftar properti Airbnb yang terletak di New York City. Tujuan utama dari dataset ini adalah untuk membantu pengguna dan pihak terkait dalam memahami pasar Airbnb di New York City, seperti tren harga, tingkat ketersediaan, dan jenis properti yang tersedia.

# %% [markdown]
# ##assess situation

# %% [markdown]
# Dataset New York City Airbnb Open Data merupakan kumpulan data tentang penyewaan akomodasi melalui platform Airbnb di kota New York. Dataset ini bisa memberikan banyak informasi yang berguna dalam bisnis understanding, seperti:
#
# 1. Mencari tahu daerah mana yang paling populer atau diminati pengguna Airbnb di New York, sehingga dapat mengoptimalkan bisnis penginapan di daerah tersebut.
# 2. Melihat jumlah ketersediaan akomodasi di suatu daerah, sehingga dapat menentukan strategi pemasaran dan promosi yang tepat untuk meningkatkan okupansi akomodasi.
# 3. Melihat kategori akomodasi yang paling banyak diminati, sehingga dapat mengembangkan atau memperbaiki fasilitas dan layanan yang ditawarkan agar sesuai dengan kebutuhan pengguna.
# 4. Melihat perbandingan harga akomodasi dengan fasilitas yang ditawarkan, sehingga dapat menentukan harga yang tepat dan bersaing di pasaran.
# 5. Melihat trend permintaan dan jumlah pengguna Airbnb di New York dari waktu ke waktu, sehingga dapat menyesuaikan strategi bisnis sesuai dengan kondisi pasar yang berubah-ubah.

# %% [markdown]
# ##determine data mining goals

# %% [markdown]
# Dalam Business Understanding pada dataset New York City Airbnb Open Data, Determine Data Mining Goals adalah proses untuk menentukan tujuan-tujuan yang ingin dicapai dari proses Data Mining. Tujuan-tujuan tersebut dapat berkaitan dengan peningkatan performa bisnis, penghematan biaya, atau peningkatan kualitas layanan yang diberikan kepada pelanggan.
#
# Contohnya, untuk dataset New York City Airbnb Open Data, tujuan dari proses Data Mining bisa menjadi:
#
# 1. Memprediksi harga sewa yang optimal untuk setiap tipe akomodasi dan wilayah di New York City, sehingga perusahaan bisa menetapkan harga yang kompetitif dan menarik bagi pelanggan.
#
# 2. Mengidentifikasi faktor-faktor yang mempengaruhi tingkat okupansi pada setiap tipe akomodasi dan wilayah di New York City, sehingga perusahaan bisa melakukan optimalisasi untuk meningkatkan tingkat okupansi dan penghasilan.
#
# 3. Menganalisis ulasan pelanggan dan menemukan pola-pola yang dapat meningkatkan kualitas layanan yang diberikan oleh perusahaan, sehingga perusahaan bisa mendapatkan kepuasan pelanggan yang lebih tinggi dan mempertahankan bisnisnya dalam jangka panjang.
#
# Dalam Determine Data Mining Goals, penting untuk mempertimbangkan tujuan-tujuan yang realistis dan spesifik, sehingga proses Data Mining dapat menghasilkan hasil yang berguna dan bernilai bagi perusahaan.

# %% [markdown]
# ##produce product plan

# %% [markdown]
# Produce product plan dalam dataset New York City Airbnb Open Data bertujuan untuk membuat rencana produk (product roadmap) yang akan dibangun untuk meningkatkan kualitas layanan yang ditawarkan oleh penyedia jasa akomodasi Airbnb di kota New York. Rencana produk tersebut dapat meliputi pengembangan fitur baru, peningkatan kualitas layanan yang sudah ada, serta pengembangan inovasi teknologi yang dapat memperbaiki pengalaman pengguna.
#
# Dataset New York City Airbnb Open Data dapat memberikan informasi tentang profil pengguna, preferensi lokasi, jenis akomodasi yang disukai, harga, dan berbagai aspek lainnya yang dapat membantu dalam memahami kebutuhan pengguna dan keinginan mereka saat memesan akomodasi. Dengan demikian, produce product plan dapat didasarkan pada analisis data yang dilakukan pada dataset ini, untuk memberikan gambaran yang lebih jelas tentang apa yang dibutuhkan oleh para pelanggan Airbnb di New York, dan bagaimana perusahaan dapat meningkatkan layanan dan produk yang ditawarkan untuk memenuhi kebutuhan mereka.

# %% [markdown]
# ##Data Understanding

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None
sns.set(style = 'whitegrid')
import textwrap

# %% [markdown]
# ###colect intial data

# %%
df = pd.read_csv('New York City Airbnb Open Data.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# df1 isinya dataset dengan label target Milk Drink Mixes
df1 = df[df['neighbourhood_group'] == 'Brooklyn']

# Menampilkan hasil filter
df1
# Out:
#              id                                             name    host_id  \
# 0          2539               Clean & quiet apt home by the park       2787
# 3          3831                  Cozy Entire Floor of Brownstone       4869
# 6          5121                                  BlissArtsSpace!       7356
# 12         5803   Lovely Room 1, Garden, Best Area, Legal rental       9744
# 15         6848                 Only 2 stops to Manhattan studio      15991
# ...         ...                                              ...        ...
# 48882  36482231                        Bushwick _ Myrtle-Wyckoff   66058896
# 48884  36482783      Brooklyn Oasis in the heart of Williamsburg  274307600
# 48887  36483152  Garden Jewel Apartment in Williamsburg New York  208514239
# 48890  36484665  Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057    Affordable room in Bushwick/East Williamsburg    6570630
#
# ...

# %%
# df2 isinya dataset dengan label target bukan Milk Drink Mixes
df2 = df[df['neighbourhood_group'] != 'Brooklyn']


# Menampilkan hasil filter
df2
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 7          5178                   Large Furnished Room Near B'way        8967
# ...         ...                                                ...        ...
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %% [markdown]
# ###describe data

# %%
# df3 isinya dataset dengan label target Revital
df3 = df[df['name'] == "Clean & quiet apt home by the park"]

# Menampilkan hasil filter
df3
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0            Brooklyn    Kensington  40.64749  -73.97237  Private room    149
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               1                  9  2018-10-19               0.21
#
#    calculated_host_listings_count  availability_365
# 0                               6               365

# %%
# df4 isinya dataset dengan label target selling_price di bawah 100
df4 = df[df['host_id'] < 2845]

# Menampilkan hasil filter
df4
# Out:
#              id                                               name  host_id  \
# 0          2539                 Clean & quiet apt home by the park     2787
# 2290    1101224                                         THE PUTNAM     2571
# 10372   7937553  Riomaggiore Room. Queen Bedroom in Bklyn Townh...     2787
# 13583  10160215                               Torre del Lago Room.     2787
# 13688  10267242  Cinque Terre Room.  Clean and Quiet Queen Bedroom     2787
# 13963  10593675  La Spezia room.  Clean, quiet and comfortable bed     2787
# 21556  17263207   Brooklyn home.  Comfort and clean. Liguria room.     2787
# 30604  23669201  Great Price: Williamsburg Brooklyn Loft off L ...     2438
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# 2290      Teedo            Brooklyn  Bedford-Stuyvesant  40.68674  -73.93845
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.select_dtypes(include=np.number)
# Out:
#              id   host_id  latitude  longitude  price  minimum_nights  \
# 0          2539      2787  40.64749  -73.97237    149               1
# 1          2595      2845  40.75362  -73.98377    225               1
# 2          3647      4632  40.80902  -73.94190    150               3
# 3          3831      4869  40.68514  -73.95976     89               1
# 4          5022      7192  40.79851  -73.94399     80              10
# ...         ...       ...       ...        ...    ...             ...
# 48890  36484665   8232441  40.67853  -73.94995     70               2
# 48891  36485057   6570630  40.70184  -73.93317     40               4
# 48892  36485431  23492952  40.81475  -73.94867    115              10
# 48893  36485609  30985759  40.75751  -73.99112     55               1
# 48894  36487245  68119814  40.76404  -73.98933     90               7
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
def tampil(kolom):
  dfnum = df[kolom]

  print("Nilai minimum         :", dfnum.min())
  print("Nilai maksimum        :", dfnum.max())
  print("Nilai standar deviasi :", dfnum.std())
  print("Nilai mean            :", dfnum.mean())

# %%
tampil("host_id")
# Out:
# Nilai minimum         : 2438
# Nilai maksimum        : 274321313
# Nilai standar deviasi : 78610967.03266661
# Nilai mean            : 67620010.64661008

# %%
tampil("price")
# Out:
# Nilai minimum         : 0
# Nilai maksimum        : 10000
# Nilai standar deviasi : 240.15416974718758
# Nilai mean            : 152.7206871868289

# %%
tampil("availability_365")
# Out:
# Nilai minimum         : 0
# Nilai maksimum        : 365
# Nilai standar deviasi : 131.62228885171479
# Nilai mean            : 112.78132733408324

# %% [markdown]
# ###Explore Data

# %% [markdown]
# ####Visualisasi Comparison

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# %matplotlib inline

# %%
  country_count = Counter(df['neighbourhood_group'].dropna().tolist()).most_common(10)
  country_idx = [country[0] for country in country_count]
  country_val = [country[1] for country in country_count]
  fig,ax = plt.subplots(figsize=(8,6))
  sns.barplot(x = country_idx,y=country_val ,ax =ax)
  plt.title('Top ten neighbourhood_group')
  plt.xlabel('neighbourhood_group')
  plt.ylabel('neighbourhood_group')
  ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %%
fig, ax = plt.subplots(figsize = (14, 6))
max_width = 13

index = df['neighbourhood_group'].fillna('NaN').value_counts().index[0:4]
count = df['neighbourhood_group'].fillna('NaN').value_counts()[0:4]
sns.barplot(x = index, y = count, order = index)
ax.set_title('Data Keseluruhan neighbourhood_group', fontsize = 18)
ax.set_xticklabels((textwrap.fill(x, max_width) for x in index), fontsize = 10)
for i, count in enumerate(count):
    ax.text(x=i-0.1 , y =count+0 , s=f"{count}" , fontdict=dict(fontsize=10))
ax.set_ylabel('Frekuensi', fontsize = 14)
ax.set_ylim(0, df['neighbourhood_group'].fillna('NaN').value_counts()[0]+10)

plt.show()

# %% [markdown]
# ####Visualisasi Distribution

# %%
# memilih beberapa fitur untuk divisualisasikan distribusinya
cols = ['latitude', 'longitude']

# menampilkan histogram dan KDE dari setiap fitur
for col in cols:
    fig, ax = plt.subplots(figsize=(8,6))
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(f"Distribution of {col}")
    plt.show()

# %%
num_cols = ['latitude', 'longitude']


fig, ax = plt.subplots(len(num_cols), 1, figsize = (14, 14))
fig.tight_layout(pad = 8)

for i, col in enumerate(num_cols):
    sns.boxplot(ax = ax[i], x = df[col], orient = 'h', color = 'aqua')
    ax[i].set_title(col, fontsize = 18)

plt.show()

# %% [markdown]
# ####Visualisasi Relationship

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.scatterplot(data=df, x="room_type", y="number_of_reviews")
ax.set_title('tipe ruangan berdasarkan terakhir angka reviews', fontsize=18)
ax.set_xlabel('room_type', fontsize=14)
ax.set_ylabel('number_of_reviews', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ####Visualisasi Composition

# %%
cormat = df.corr()
fig, ax = plt.subplots(figsize = (12, 8))
sns.heatmap(ax = ax, data = cormat, annot = True)
ax.set_yticklabels(cormat.columns, rotation = 0)
plt.show()
# Out:
# <ipython-input-32-d3c681067d7a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cormat = df.corr()

# %%
#Calculate count of each Level category
level_count = df['neighbourhood_group'].value_counts()

#Create pie chart for Level categories
fig, ax = plt.subplots(figsize=(10, 8))
ax.pie(level_count, labels=level_count.index, autopct='%1.1f%%')
ax.set_title('Persentase neighbourhood_group')
plt.show()

# %% [markdown]
# ###verify data quality

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Check for duplicates
duplicate_rows = df.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
# Check for outliers
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
outliers = ((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum()
print("Outliers:\n", outliers)
# Out:
# Outliers:
#  availability_365                     0
# calculated_host_listings_count    7081
# host_id                           1526
# host_name                            0
# id                                   0
# last_review                          0
# latitude                           425
# longitude                         2833
# minimum_nights                    6607
# name                                 0
# neighbourhood                        0
# neighbourhood_group                  0
# number_of_reviews                 6021
# price                             2972
# reviews_per_month                 1793
# room_type                            0
# dtype: int64
# <ipython-input-36-650d731e3b3f>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# ...

# %%
# Check data types
print("Data types:\n", df.dtypes)
# Out:
# Data types:
#  id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# ##Data Preparation

# %% [markdown]
# ###select data

# %%
import pandas as pd

# %%
df = pd.read_csv('New York City Airbnb Open Data.csv')

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Membuat hanya menampikan 2 Kolom
selected_data = df[["host_name", "neighbourhood_group"]]

# Menampilkan Perintah
selected_data.head()
# Out:
#      host_name neighbourhood_group
# 0         John            Brooklyn
# 1     Jennifer           Manhattan
# 2    Elisabeth           Manhattan
# 3  LisaRoxanne            Brooklyn
# 4        Laura           Manhattan

# %%
# Membuat hanya menampikan 3 Kolom
selected_data = df[["host_name", "neighbourhood_group", "neighbourhood"]]

# Menampilkan Perintah
selected_data.head()
# Out:
#      host_name neighbourhood_group neighbourhood
# 0         John            Brooklyn    Kensington
# 1     Jennifer           Manhattan       Midtown
# 2    Elisabeth           Manhattan        Harlem
# 3  LisaRoxanne            Brooklyn  Clinton Hill
# 4        Laura           Manhattan   East Harlem

# %% [markdown]
# ###clean data

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.isna().sum() / len(df) * 100
# Out:
# id                                 0.000000
# name                               0.032723
# host_id                            0.000000
# host_name                          0.042949
# neighbourhood_group                0.000000
# neighbourhood                      0.000000
# latitude                           0.000000
# longitude                          0.000000
# room_type                          0.000000
# price                              0.000000
# minimum_nights                     0.000000
# number_of_reviews                  0.000000
# last_review                       20.558339
# reviews_per_month                 20.558339
# calculated_host_listings_count     0.000000
# availability_365                   0.000000
# dtype: float64

# %%
df["name"] = df["name"].fillna(df["name"].mode()[0])
# df["host_name"] = df["host_name"].fillna(df["host_name"].mode()[0])
# df["last_review"] = df["last_review"].fillna(df["last_review"].mode()[0])
df["reviews_per_month"] = df["reviews_per_month"].fillna(df["reviews_per_month"].mode()[0])

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.isna().sum() / len(df) * 100
# Out:
# id                                 0.000000
# name                               0.000000
# host_id                            0.000000
# host_name                          0.042949
# neighbourhood_group                0.000000
# neighbourhood                      0.000000
# latitude                           0.000000
# longitude                          0.000000
# room_type                          0.000000
# price                              0.000000
# minimum_nights                     0.000000
# number_of_reviews                  0.000000
# last_review                       20.558339
# reviews_per_month                  0.000000
# calculated_host_listings_count     0.000000
# availability_365                   0.000000
# dtype: float64

# %% [markdown]
# ###construct data

# %%
import pandas as pd

# %%
df = pd.read_csv('New York City Airbnb Open Data.csv')

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Create a new feature that calculates the difference between the maximum and minimum values of each banknote
df["host_name	"] = df["latitude"] + df["longitude"] + df["price"]

# Display the first few rows of the modified dataset
print(df.head())
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Menambahkan kolom diskon
df['diskon'] = df['price'] / ((df['calculated_host_listings_count'] / 100) ** 2)

# Mengubah nilai kategori menjadi numerik pada kolom last_review
df['last_review'] = df['last_review'].map({'IN_STOCK': 0, 'OUT_STOCK': 1})

# Menghapus kolom-kolom yang tidak diperlukan
df = df.drop(['last_review'], axis=1)

# Menampilkan lima baris pertama dari dataset yang telah diproses
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# ...

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ###integrate data

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Melakukan integrasi data dengan menambahkan kolom baru
df['total_review'] = df['number_of_reviews'] + df['minimum_nights']

# mengubah nilai 'nilai_awal' pada kolom 'last_review' menjadi 'nilai_baru'
df.loc[df['minimum_nights'] == 'nilai_awal', 'minimum_nights'] = 'nilai_baru'

# menyimpan dataset yang telah diubah
df.to_csv('integrity data.csv', index=False)

print("berhasil membuat dataset baru dan menambahkan 1 kolom baru yaitu total price")
# Out:
# berhasil membuat dataset baru dan menambahkan 1 kolom baru yaitu total price

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  object
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ###format data

# %%
# Mengganti nilai null dengan nilai rata-rata
mean_value = df['price'].mean()
df['price'] = df['price'].fillna(mean_value)

# Menghapus baris yang duplikat
df = df.drop_duplicates()

# Mengurutkan data berdasarkan kolom5
df = df.sort_values('minimum_nights')

# Menyimpan hasil pengolahan data ke file csv
df.to_csv('data_cleaned.csv', index=False)

# %%
df
# Out:
#              id                                          name    host_id  \
# 0          2539            Clean & quiet apt home by the park       2787
# 16078  12990578  Cozy Room with Window View near Times Square   49447536
# 16090  13001082                       Share space in E Harlem    4112409
# 16096  13006002  Cozy room in a beautiful and quite apartment   31996442
# 16099  13007839                        Second floor apartment   71754921
# ...         ...                                           ...        ...
# 13404  10053943            Historic Designer 2 Bed. Apartment    2697686
# 26341  20990053               Beautiful place in Brooklyn! #2  151084261
# 38664  30378211                  Shared Studio (females only)  200401254
# 2854    1615764                                           NaN    6676776
# 5767    4204302              Prime W. Village location 1 bdrm   17550546
#
#        host_name neighbourhood_group      neighbourhood  latitude  longitude  \
# ...

# %%
#Mengambil sebagian data dari dataset awal
df2 = df.iloc[0:5000, :]

df2
# Out:
#              id                                             name    host_id  \
# 0          2539               Clean & quiet apt home by the park       2787
# 16078  12990578     Cozy Room with Window View near Times Square   49447536
# 16090  13001082                          Share space in E Harlem    4112409
# 16096  13006002     Cozy room in a beautiful and quite apartment   31996442
# 16099  13007839                           Second floor apartment   71754921
# ...         ...                                              ...        ...
# 34756  27551619              Spacious room with private bathroom   39285391
# 29766  22878805             Clean and Classy Central Park Studio     425702
# 29764  22878090                  HUGE studio apartment near ALL!  116754031
# 29760  22869995                                       Indo Sweet  169211917
# 34763  27552868  VIP staycation deluxe movie theater indoor pool   21963202
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 5767
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  object
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# ##Modeling

# %% [markdown]
# ###Preprocessing

# %%
# Untuk Clustering
from sklearn.cluster import KMeans


# Untuk scalling dan normalisasi
from sklearn.preprocessing import StandardScaler

# Metric Pengukuran
# sumber : https://towardsdatascience.com/performance-metrics-in-machine-learning-part-3-clustering-d69550662dc6
from sklearn.metrics import silhouette_score,calinski_harabasz_score,davies_bouldin_score

import numpy as np

# %%
df = df.drop('host_name',axis=1)

# %% [markdown]
# ###Encoding

# %%
# PreProcessing
# Encoding DataTraining
X_train = pd.get_dummies(df2)
# Out:
# <ipython-input-64-ec8eb537fa99>:3: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   X_train = pd.get_dummies(df2)

# %%
X_train.columns
# Out:
# Index(['id', 'host_id', 'latitude', 'longitude', 'price', 'number_of_reviews',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'host_name\t',
#        ...
#        'neighbourhood_Williamsbridge', 'neighbourhood_Williamsburg',
#        'neighbourhood_Windsor Terrace', 'neighbourhood_Woodhaven',
#        'neighbourhood_Woodlawn', 'neighbourhood_Woodside',
#        'room_type_Entire home/apt', 'room_type_Private room',
#        'room_type_Shared room', 'minimum_nights_1'],
#       dtype='object', length=7420)

# %% [markdown]
# ##Modeling

# %%
# PreProcessing
# Encoding DataTraining
X_train = pd.get_dummies(df2)
# Out:
# <ipython-input-66-ec8eb537fa99>:3: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   X_train = pd.get_dummies(df2)

# %%
X_train.columns
# Out:
# Index(['id', 'host_id', 'latitude', 'longitude', 'price', 'number_of_reviews',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'host_name\t',
#        ...
#        'neighbourhood_Williamsbridge', 'neighbourhood_Williamsburg',
#        'neighbourhood_Windsor Terrace', 'neighbourhood_Woodhaven',
#        'neighbourhood_Woodlawn', 'neighbourhood_Woodside',
#        'room_type_Entire home/apt', 'room_type_Private room',
#        'room_type_Shared room', 'minimum_nights_1'],
#       dtype='object', length=7420)

# %%
sse = [] #Daftar SSE
K = range(2,10) #Banyak Cluster hingga 30
# # Perulangan hingga 30 Cluster
X_train = X_train.dropna()
for k in K:
    kmeans = KMeans(n_clusters= k,random_state=42).fit(X_train)
#     #Mendapatkan SSE dan append ke list sse
    sse.append(kmeans.inertia_)
  # # Membuat plot K terhadap SSE
plt.plot(K,sse, "bx-")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
class Kmeans:
    """The k-means algorithm."""

    def __init__(self, n_clusters):
        self.data = pd.DataFrame()
        self.n_clusters = n_clusters
        self.centroids = pd.DataFrame()
        self.clusters = np.ndarray(1)
        self.old_centroids = pd.DataFrame()
        self.verbose = False
        self.predictions = list()

    def train(self, df, verbose):
        self.verbose = verbose
        self.data = df.copy(deep=True)
        self.clusters = np.zeros(len(self.data))

        if 'species' in self.data.columns:
            self.data.drop('species', axis=1, inplace=True)

        # Randomly initialize centroids
        unique_rows = self.data.drop_duplicates()
        unique_rows.reset_index(drop=True, inplace=True)
        self.centroids = unique_rows.sample(n=self.n_clusters)
        self.centroids.reset_index(drop=True, inplace=True)

        if self.verbose:
            print("\nRandomly initiated centroids:")
            print(self.centroids)

        # Initialize old centroids as a matrix of all 0's
        self.old_centroids = pd.DataFrame(np.zeros(shape=(self.n_clusters, self.data.shape[1])),
                                          columns=self.data.columns)

        # Compare every data point in our dataset to each of the k-means and assign each point to closest cluster
        while not self.old_centroids.equals(self.centroids):
            
            if self.verbose:
                time.sleep(3)

            # Stash old centroids
            self.old_centroids = self.centroids.copy(deep=True)

            # Iterate through each data point in the matrix
            for row_i in range(0, len(self.data)):
                distances = list()
                point = self.data.iloc[row_i]

                # Calculate the distance between the current point and each of the centroids
                for row_c in range(0, len(self.centroids)):
                    centroid = self.centroids.iloc[row_c]
                    distances.append(np.linalg.norm(point - centroid))

                # Assign this data point to a cluster
                self.clusters[row_i] = np.argmin(distances)

            # For each cluster extract the values which now belong to each cluster and calculate new k-means
            for cls in range(0, self.n_clusters):

                cls_idx = np.where(self.clusters == cls)[0]

                if len(cls_idx) == 0:
                    self.centroids.loc[cls] = self.old_centroids.loc[cls]
                else:
                    # Set the new k-mean to the mean value of the data points within this cluster
                    self.centroids.loc[cls] = self.data.iloc[cls_idx].mean()
                    
                if self.verbose:
                    print("\nRow indices belonging to cluster {}: [n={}]".format(cls, len(cls_idx)))
                    print(cls_idx)

            if self.verbose:
                print("\nOld centroids:")
                print(self.old_centroids)
                print("New centroids:")
                print(self.centroids)

# %%
kmeans = Kmeans(n_clusters = 4)
kmeans.train(df=X_train, verbose = False)

# %%
X_train['cluster']=kmeans.clusters
centroids = kmeans.centroids
centroids['cluster'] = 'centroid'
all_df = pd.concat([X_train, centroids])
# Out:
# <ipython-input-71-3de36e4dca6f>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   centroids['cluster'] = 'centroid'

# %%
all_df
# Out:
#                  id       host_id   latitude  longitude       price  \
# 0      2.539000e+03  2.787000e+03  40.647490 -73.972370  149.000000
# 16078  1.299058e+07  4.944754e+07  40.754840 -73.992200  100.000000
# 16090  1.300108e+07  4.112409e+06  40.791930 -73.943900   45.000000
# 16096  1.300600e+07  3.199644e+07  40.694750 -73.968480   70.000000
# 40990  3.188105e+07  2.389539e+08  40.663710 -73.987600  110.000000
# ...             ...           ...        ...        ...         ...
# 29760  2.287000e+07  1.692119e+08  40.640160 -73.941190   80.000000
# 0      3.203012e+07  2.314453e+08  40.728052 -73.932479  125.203704
# 1      2.637453e+07  1.397739e+08  40.733382 -73.929694  110.772853
# 2      1.521551e+07  5.913588e+07  40.732818 -73.942111  113.333333
# 3      1.571931e+07  1.399971e+07  40.727478 -73.953562  117.914812
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %% [markdown]
# ####Mengembalikan data yang sudah di encoding dan membuat dataframe baru yaitu X_train_decoded

# %%
# Membuat DataFrame kosong untuk hasil decode
X_train_decoded = pd.DataFrame()

# Kolom-kolom yang akan digabungkan
id_cols = ['id', 'host_id']
review_cols = ['number_of_reviews',	'reviews_per_month']
neighbourhood_cols =['neighbourhood_Williamsburg',	'neighbourhood_Windsor Terrace',	'neighbourhood_Woodhaven',	'neighbourhood_Woodlawn',	'neighbourhood_Woodside']
room_cols =['room_type_Entire home/apt',	'room_type_Private room',	'room_type_Shared room']


# Menambahkan kolom-kolom numerik
X_train_decoded['price'] = all_df['price']
X_train_decoded['number_of_reviews'] = all_df['number_of_reviews']
X_train_decoded['reviews_per_month'] = all_df['reviews_per_month']
X_train_decoded['calculated_host_listings_count'] = all_df['calculated_host_listings_count']
X_train_decoded['minimum_nights_1'] = all_df['minimum_nights_1']
X_train_decoded['cluster'] = all_df['cluster']

# Menggabungkan kolom-kolom yang sama dan menjadikan sebagai satu kolom
X_train_decoded['id'] = all_df[id_cols].idxmax(axis=1).str.split('_', expand=True)[1]
X_train_decoded['reviews'] = all_df[review_cols].idxmax(axis=1).str.split('_', expand=True)[2]
X_train_decoded['neighbourhood'] = all_df[neighbourhood_cols].idxmax(axis=1).str.split('_', expand=True)[1]
X_train_decoded['room'] = all_df[room_cols].idxmax(axis=1).str.split('_', expand=True)[2]
X_train_decoded
# Out:
#             price  number_of_reviews  reviews_per_month  \
# 0      149.000000           9.000000           0.210000
# 16078  100.000000           1.000000           0.030000
# 16090   45.000000          52.000000           1.410000
# 16096   70.000000           3.000000           0.080000
# 40990  110.000000          48.000000           9.930000
# ...           ...                ...                ...
# 29760   80.000000           1.000000           0.070000
# 0      125.203704          14.998457           3.422963
# 1      110.772853          31.844875           2.705069
# 2      113.333333          43.983721           1.614752
# 3      117.914812          33.366179           1.405054
#
#        calculated_host_listings_count  minimum_nights_1   cluster    id  \
# 0                            6.000000                 1       3.0    id
# 16078                        1.000000                 1       2.0    id
# 16090                        1.000000                 1       3.0  None
# ...

# %% [markdown]
# #### 3D Plotting

# %%
px.scatter_3d(X_train_decoded, x='price', y='number_of_reviews', z='calculated_host_listings_count', color='cluster',color_continuous_scale=['#ADFF2F', '#19A3E8', '#FF5A44', '#FFD326'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Analisis Cluster

# %%
def plot_cluster(cluster_df):
    plot, ax = plt.subplots(3,4,figsize=(55,15),constrained_layout=True)
    cols = ['price', 'number_of_reviews', 'minimum_nights_1']
    category_counts = cluster_df['id'].value_counts()
    sns.barplot(x=category_counts.index, y=category_counts.values, ax=ax[2][2])
    for i,col in enumerate(cols):
        sns.histplot(data=cluster_df, x=col, ax=ax[0][i], kde=True)
        sns.boxplot(data=cluster_df, x=col, ax=ax[1][i])
    sns.countplot(data=cluster_df, x="room", ax=ax[2][0])
    sns.countplot(data=cluster_df, x="reviews", ax=ax[2][1])
    sns.countplot(data=cluster_df, x="neighbourhood", ax=ax[2][3])

# %%
cluster1 = X_train_decoded[X_train_decoded['cluster'] == 0]
cluster2 = X_train_decoded[X_train_decoded['cluster'] == 1]
cluster3 = X_train_decoded[X_train_decoded['cluster'] == 2]
cluster4 = X_train_decoded[X_train_decoded['cluster'] == 3]

# %% [markdown]
# ###Cluster 1

# %%
cluster1.describe()
# Out:
#              price  number_of_reviews  reviews_per_month  \
# count   648.000000         648.000000         648.000000
# mean    125.203704          14.998457           3.422963
# std     133.869086          16.078488           3.524999
# min      21.000000           1.000000           0.150000
# 25%      55.000000           4.000000           1.215000
# 50%      80.000000          11.000000           2.775000
# 75%     150.000000          20.000000           4.732500
# max    1497.000000         156.000000          58.500000
#
#        calculated_host_listings_count  minimum_nights_1
# count                      648.000000             648.0
# mean                         3.751543               1.0
# std                          4.622203               0.0
# min                          1.000000               1.0
# 25%                          1.000000               1.0
# 50%                          2.000000               1.0
# 75%                          5.000000               1.0
# ...

# %%
plot_cluster(cluster1)

# %% [markdown]
# ciri-ciri cluster 1:

# %% [markdown]
# ###Cluster 2

# %%
# Menampilkan deskripsi statistik dari cluster 2
cluster2.describe()
# Out:
#              price  number_of_reviews  reviews_per_month  \
# count   361.000000         361.000000         361.000000
# mean    110.772853          31.844875           2.705069
# std     202.989705          48.490472           2.621578
# min      19.000000           1.000000           0.030000
# 25%      55.000000           5.000000           0.590000
# 50%      80.000000          12.000000           2.130000
# 75%     120.000000          37.000000           3.800000
# max    3613.000000         341.000000          17.820000
#
#        calculated_host_listings_count  minimum_nights_1
# count                      361.000000             361.0
# mean                         2.714681               1.0
# std                          3.708703               0.0
# min                          1.000000               1.0
# 25%                          1.000000               1.0
# 50%                          2.000000               1.0
# 75%                          3.000000               1.0
# ...

# %%
# Menampilkan deskripsi statistik dari cluster 2
plot_cluster(cluster2)

# %% [markdown]
# ciri-ciri cluster 2 :

# %% [markdown]
# ###Cluster 3

# %%
# Menampilkan deskripsi statistik dari cluster 3
cluster3.describe()
# Out:
#              price  number_of_reviews  reviews_per_month  \
# count  1290.000000        1290.000000        1290.000000
# mean    113.333333          43.983721           1.614752
# std     124.361197          71.251544           2.106351
# min      19.000000           1.000000           0.020000
# 25%      60.000000           2.000000           0.080000
# 50%      80.000000          11.000000           0.630000
# 75%     129.000000          55.000000           2.530000
# max    2000.000000         629.000000          14.580000
#
#        calculated_host_listings_count  minimum_nights_1
# count                     1290.000000            1290.0
# mean                         1.776744               1.0
# std                          1.469552               0.0
# min                          1.000000               1.0
# 25%                          1.000000               1.0
# 50%                          1.000000               1.0
# 75%                          2.000000               1.0
# ...

# %%
# Menampilkan distribusi dari cluster3
plot_cluster(cluster3)

# %% [markdown]
# ciri_ciri cluster 3 :

# %% [markdown]
# ###Cluster 4

# %%
#Menampilkan deskripsi statistik dari cluster 4
cluster4.describe()
# Out:
#              price  number_of_reviews  reviews_per_month  \
# count  1573.000000        1573.000000        1573.000000
# mean    117.914812          33.366179           1.405054
# std     114.586386          56.602949           1.877739
# min      22.000000           1.000000           0.020000
# 25%      60.000000           2.000000           0.070000
# 50%      90.000000           8.000000           0.410000
# 75%     138.000000          34.000000           2.280000
# max    2000.000000         424.000000          13.130000
#
#        calculated_host_listings_count  minimum_nights_1
# count                     1573.000000            1573.0
# mean                         2.048951               1.0
# std                          2.435847               0.0
# min                          1.000000               1.0
# 25%                          1.000000               1.0
# 50%                          1.000000               1.0
# 75%                          2.000000               1.0
# ...

# %%
# Menampilkan distribusi dari cluster 4
plot_cluster(cluster4)

# %% [markdown]
# ciri-ciri cluster 4 :

# %% [markdown]
# ##Evaluation

# %%
# Menghitung nilai Silhouette Score
silhouette_avg = silhouette_score(X_train.drop('cluster', axis=1), kmeans.clusters)

# Menghitung nilai Calinski-Harabasz Index
ch_score= calinski_harabasz_score(X_train.drop('cluster', axis=1), kmeans.clusters)

# Menghitung nilai Davies-Bouldin Index
db_score= davies_bouldin_score(X_train.drop('cluster', axis=1), kmeans.clusters)

# Create dataframe for metrics and scores
metrics = ["Silhouette Score", "Calinski-Harabasz Score", "Davies-Bouldin Score"]
scores = [silhouette_avg, ch_score, db_score]
df_scores = pd.DataFrame({'Metric': metrics, 'Score': scores})

# reset index dataframe
df_scores = df_scores.reset_index(drop=True)

# ubah nama axis pada index dan kolom
df_scores = df_scores.rename_axis('', axis=0).rename_axis('Metrics', axis=1)

# Display dataframe as table without index column
display(df_scores.style.hide_index())
# Out:
# <ipython-input-85-caf45928800c>:22: FutureWarning:
#
# this method is deprecated in favour of `Styler.hide(axis="index")`
# <style type="text/css">
# </style>
# <table id="T_26039" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_26039_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_26039_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_26039_row0_col0" class="data row0 col0" >Silhouette Score</td>
#       <td id="T_26039_row0_col1" class="data row0 col1" >0.561593</td>
#     </tr>
#     <tr>
#       <td id="T_26039_row1_col0" class="data row1 col0" >Calinski-Harabasz Score</td>
#       <td id="T_26039_row1_col1" class="data row1 col1" >24834.055931</td>
#     </tr>
#     <tr>
#       <td id="T_26039_row2_col0" class="data row2 col0" >Davies-Bouldin Score</td>
#       <td id="T_26039_row2_col1" class="data row2 col1" >0.558767</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##Deployment

# %%
# Export df yang sebelum encoding
df #df3 dipakai karena ini df yang setelah cleaning dan sebelum encoding
df.to_csv("integrity data.csv")

# %% [markdown]
# ![Unsupervised_Kel_5_C1_page-0001.jpg](data:image/jpeg;base64,...)
